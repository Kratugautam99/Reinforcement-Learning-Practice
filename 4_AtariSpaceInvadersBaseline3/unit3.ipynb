# %% [markdown]
# # Unit 3: Deep Q-Learning with Atari Games 👾 using RL Baselines3 Zoo
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/unit4/thumbnail.jpg" alt="Unit 3 Thumbnail">
#
# In this notebook, **you'll train a Deep Q-Learning agent** playing Space Invaders using [RL Baselines3 Zoo](https://github.com/DLR-RM/rl-baselines3-zoo), a training framework based on [Stable-Baselines3](https://stable-baselines3.readthedocs.io/en/master/) that provides scripts for training, evaluating agents, tuning hyperparameters, plotting results and recording videos.
#
# We're using the [RL-Baselines-3 Zoo integration, a vanilla version of Deep Q-Learning](https://stable-baselines3.readthedocs.io/en/master/modules/dqn.html) with no extensions such as Double-DQN, Dueling-DQN, and Prioritized Experience Replay.
#
# ⬇️ Here is an example of what **you will achieve** ⬇️

# %%
# %%html
# <video controls autoplay><source src="https://huggingface.co/KraTUZen/ppo-SpaceInvadersNoFrameskip-v4/resolve/main/replay.mp4" type="video/mp4"></video>
# Out:
# <video controls autoplay><source src="https://huggingface.co/ThomasSimonini/ppo-SpaceInvadersNoFrameskip-v4/resolve/main/replay.mp4" type="video/mp4"></video>

# %% [markdown]
# ### 🎮 Environments:
#
# - [SpacesInvadersNoFrameskip-v4](https://gymnasium.farama.org/environments/atari/space_invaders/)
#
# You can see the difference between Space Invaders versions here 👉 https://gymnasium.farama.org/environments/atari/space_invaders/#variants
#
# ### 📚 RL-Library:
#
# - [RL-Baselines3-Zoo](https://github.com/DLR-RM/rl-baselines3-zoo)

# %% [markdown]
# ## Objectives of this notebook 🏆
# At the end of the notebook, you will:
# - Be able to understand deeper **how RL Baselines3 Zoo works**.
# - Be able to **push your trained agent and the code to the Hub** with a nice video replay and an evaluation score 🔥.

# %% [markdown]
# ## This notebook is from Deep Reinforcement Learning Course
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/deep-rl-course-illustration.jpg" alt="Deep RL Course illustration"/>

# %% [markdown]
# In this free course, you will:
#
# - 📖 Study Deep Reinforcement Learning in **theory and practice**.
# - 🧑‍💻 Learn to **use famous Deep RL libraries** such as Stable Baselines3, RL Baselines3 Zoo, CleanRL and Sample Factory 2.0.
# - 🤖 Train **agents in unique environments**
#
# And more check 📚 the syllabus 👉 https://simoninithomas.github.io/deep-rl-course
#
# Don’t forget to **<a href="http://eepurl.com/ic5ZUD">sign up to the course</a>** (we are collecting your email to be able to **send you the links when each Unit is published and give you information about the challenges and updates).**
#
#
# The best way to keep in touch is to join our discord server to exchange with the community and with us 👉🏻 https://discord.gg/ydHrjt3WP5

# %% [markdown]
# ## Prerequisites 🏗️
# Before diving into the notebook, you need to:
#
# 🔲 📚 **[Study Deep Q-Learning by reading Unit 3](https://huggingface.co/deep-rl-course/unit3/introduction)**  🤗

# %% [markdown]
# We're constantly trying to improve our tutorials, so **if you find some issues in this notebook**, please [open an issue on the Github Repo](https://github.com/huggingface/deep-rl-class/issues).

# %% [markdown]
# # Let's train a Deep Q-Learning agent playing Atari' Space Invaders 👾 and upload it to the Hub.
#
# We strongly recommend students **to use Google Colab for the hands-on exercises instead of running them on their personal computers**.
#
# By using Google Colab, **you can focus on learning and experimenting without worrying about the technical aspects of setting up your environments**.
#
# To validate this hands-on for the certification process, you need to push your trained model to the Hub and **get a result of >= 200**.
#
# To find your result, go to the leaderboard and find your model, **the result = mean_reward - std of reward**
#
# For more information about the certification process, check this section 👉 https://huggingface.co/deep-rl-course/en/unit0/introduction#certification-process

# %% [markdown]
# ## An advice 💡
# It's better to run this colab in a copy on your Google Drive, so that **if it timeouts** you still have the saved notebook on your Google Drive and do not need to fill everything from scratch.
#
# To do that you can either do `Ctrl + S` or `File > Save a copy in Google Drive.`
#
# Also, we're going to **train it for 90 minutes with 1M timesteps**. By typing `!nvidia-smi` will tell you what GPU you're using.
#
# And if you want to train more such 10 million steps, this will take about 9 hours, potentially resulting in Colab timing out. In that case, I recommend running this on your local computer (or somewhere else). Just click on: `File>Download`.

# %% [markdown]
# ## Set the GPU 💪
# - To **accelerate the agent's training, we'll use a GPU**. To do that, go to `Runtime > Change Runtime type`
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/gpu-step1.jpg" alt="GPU Step 1">

# %% [markdown]
# - `Hardware Accelerator > GPU`
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/gpu-step2.jpg" alt="GPU Step 2">

# %% [markdown]
# # Install RL-Baselines3 Zoo and its dependencies 📚
#
# If you see `ERROR: pip's dependency resolver does not currently take into account all the packages that are installed.` **this is normal and it's not a critical error** there's a conflict of version. But the packages we need are installed.

# %%
# !pip install git+https://github.com/DLR-RM/rl-baselines3-zoo
# Out:
# Collecting git+https://github.com/DLR-RM/rl-baselines3-zoo
#   Cloning https://github.com/DLR-RM/rl-baselines3-zoo to /tmp/pip-req-build-uug_w_px
#   Running command git clone --filter=blob:none --quiet https://github.com/DLR-RM/rl-baselines3-zoo /tmp/pip-req-build-uug_w_px
#   Resolved https://github.com/DLR-RM/rl-baselines3-zoo to commit d42f9159bfa897871ea912a8ef5ccc92ba364948
#   Running command git submodule update --init --recursive -q
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting sb3_contrib<3.0,>=2.8.0a0 (from rl_zoo3==2.8.0a1)
#   Downloading sb3_contrib-2.8.0a0-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: gymnasium<1.3.0,>=0.29.1 in /usr/local/lib/python3.12/dist-packages (from rl_zoo3==2.8.0a1) (1.2.3)
# Collecting huggingface_sb3<4.0,>=3.0 (from rl_zoo3==2.8.0a1)
#   Downloading huggingface_sb3-3.0-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from rl_zoo3==2.8.0a1) (4.67.3)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from rl_zoo3==2.8.0a1) (13.9.4)
# Collecting optuna>=3.0 (from rl_zoo3==2.8.0a1)
#   Downloading optuna-4.7.0-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from rl_zoo3==2.8.0a1) (6.0.3)
# Collecting pytablewriter~=1.2 (from rl_zoo3==2.8.0a1)
#   Downloading pytablewriter-1.2.1-py3-none-any.whl.metadata (38 kB)
# Collecting shimmy~=2.0 (from rl_zoo3==2.8.0a1)
#   Downloading Shimmy-2.0.0-py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium<1.3.0,>=0.29.1->rl_zoo3==2.8.0a1) (2.0.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium<1.3.0,>=0.29.1->rl_zoo3==2.8.0a1) (3.1.2)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium<1.3.0,>=0.29.1->rl_zoo3==2.8.0a1) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.12/dist-packages (from gymnasium<1.3.0,>=0.29.1->rl_zoo3==2.8.0a1) (0.0.4)
# Collecting huggingface-hub~=0.8 (from huggingface_sb3<4.0,>=3.0->rl_zoo3==2.8.0a1)
#   Downloading huggingface_hub-0.36.2-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: wasabi in /usr/local/lib/python3.12/dist-packages (from huggingface_sb3<4.0,>=3.0->rl_zoo3==2.8.0a1) (1.1.3)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from optuna>=3.0->rl_zoo3==2.8.0a1) (1.18.4)
# Collecting colorlog (from optuna>=3.0->rl_zoo3==2.8.0a1)
#   Downloading colorlog-6.10.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from optuna>=3.0->rl_zoo3==2.8.0a1) (26.0)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from optuna>=3.0->rl_zoo3==2.8.0a1) (2.0.47)
# Requirement already satisfied: setuptools>=38.3.0 in /usr/local/lib/python3.12/dist-packages (from pytablewriter~=1.2->rl_zoo3==2.8.0a1) (75.2.0)
# Collecting DataProperty<2,>=1.1.0 (from pytablewriter~=1.2->rl_zoo3==2.8.0a1)
#   Downloading DataProperty-1.1.0-py3-none-any.whl.metadata (11 kB)
# Collecting mbstrdecoder<2,>=1.0.0 (from pytablewriter~=1.2->rl_zoo3==2.8.0a1)
#   Downloading mbstrdecoder-1.1.4-py3-none-any.whl.metadata (4.3 kB)
# Collecting pathvalidate<4,>=2.3.0 (from pytablewriter~=1.2->rl_zoo3==2.8.0a1)
#   Downloading pathvalidate-3.3.1-py3-none-any.whl.metadata (12 kB)
# Collecting tabledata<2,>=1.3.1 (from pytablewriter~=1.2->rl_zoo3==2.8.0a1)
#   Downloading tabledata-1.3.4-py3-none-any.whl.metadata (3.7 kB)
# Collecting tcolorpy<1,>=0.0.5 (from pytablewriter~=1.2->rl_zoo3==2.8.0a1)
#   Downloading tcolorpy-0.1.7-py3-none-any.whl.metadata (6.3 kB)
# Collecting typepy<2,>=1.3.2 (from typepy[datetime]<2,>=1.3.2->pytablewriter~=1.2->rl_zoo3==2.8.0a1)
#   Downloading typepy-1.3.4-py3-none-any.whl.metadata (9.2 kB)
# Collecting stable_baselines3<3.0,>=2.8.0a0 (from sb3_contrib<3.0,>=2.8.0a0->rl_zoo3==2.8.0a1)
#   Downloading stable_baselines3-2.8.0a2-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->rl_zoo3==2.8.0a1) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->rl_zoo3==2.8.0a1) (2.19.2)
# Requirement already satisfied: Mako in /usr/local/lib/python3.12/dist-packages (from alembic>=1.5.0->optuna>=3.0->rl_zoo3==2.8.0a1) (1.3.10)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from huggingface-hub~=0.8->huggingface_sb3<4.0,>=3.0->rl_zoo3==2.8.0a1) (3.24.3)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub~=0.8->huggingface_sb3<4.0,>=3.0->rl_zoo3==2.8.0a1) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub~=0.8->huggingface_sb3<4.0,>=3.0->rl_zoo3==2.8.0a1) (1.3.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from huggingface-hub~=0.8->huggingface_sb3<4.0,>=3.0->rl_zoo3==2.8.0a1) (2.32.4)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->rl_zoo3==2.8.0a1) (0.1.2)
# Requirement already satisfied: chardet<6,>=3.0.4 in /usr/local/lib/python3.12/dist-packages (from mbstrdecoder<2,>=1.0.0->pytablewriter~=1.2->rl_zoo3==2.8.0a1) (5.2.0)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy>=1.4.2->optuna>=3.0->rl_zoo3==2.8.0a1) (3.3.2)
# Requirement already satisfied: torch<3.0,>=2.3 in /usr/local/lib/python3.12/dist-packages (from stable_baselines3<3.0,>=2.8.0a0->sb3_contrib<3.0,>=2.8.0a0->rl_zoo3==2.8.0a1) (2.10.0+cu128)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from stable_baselines3<3.0,>=2.8.0a0->sb3_contrib<3.0,>=2.8.0a0->rl_zoo3==2.8.0a1) (2.2.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from stable_baselines3<3.0,>=2.8.0a0->sb3_contrib<3.0,>=2.8.0a0->rl_zoo3==2.8.0a1) (3.10.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.8.0 in /usr/local/lib/python3.12/dist-packages (from typepy[datetime]<2,>=1.3.2->pytablewriter~=1.2->rl_zoo3==2.8.0a1) (2.9.0.post0)
# Requirement already satisfied: pytz>=2018.9 in /usr/local/lib/python3.12/dist-packages (from typepy[datetime]<2,>=1.3.2->pytablewriter~=1.2->rl_zoo3==2.8.0a1) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil<3.0.0,>=2.8.0->typepy[datetime]<2,>=1.3.2->pytablewriter~=1.2->rl_zoo3==2.8.0a1) (1.17.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.8.0a0->sb3_contrib<3.0,>=2.8.0a0->rl_zoo3==2.8.0a1) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.8.0a0->sb3_contrib<3.0,>=2.8.0a0->rl_zoo3==2.8.0a1) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.8.0a0->sb3_contrib<3.0,>=2.8.0a0->rl_zoo3==2.8.0a1) (3.1.6)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.8.0a0->sb3_contrib<3.0,>=2.8.0a0->rl_zoo3==2.8.0a1) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.8.0a0->sb3_contrib<3.0,>=2.8.0a0->rl_zoo3==2.8.0a1) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.8.0a0->sb3_contrib<3.0,>=2.8.0a0->rl_zoo3==2.8.0a1) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.8.0a0->sb3_contrib<3.0,>=2.8.0a0->rl_zoo3==2.8.0a1) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.8.0a0->sb3_contrib<3.0,>=2.8.0a0->rl_zoo3==2.8.0a1) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.8.0a0->sb3_contrib<3.0,>=2.8.0a0->rl_zoo3==2.8.0a1) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.8.0a0->sb3_contrib<3.0,>=2.8.0a0->rl_zoo3==2.8.0a1) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.8.0a0->sb3_contrib<3.0,>=2.8.0a0->rl_zoo3==2.8.0a1) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.8.0a0->sb3_contrib<3.0,>=2.8.0a0->rl_zoo3==2.8.0a1) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.8.0a0->sb3_contrib<3.0,>=2.8.0a0->rl_zoo3==2.8.0a1) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.8.0a0->sb3_contrib<3.0,>=2.8.0a0->rl_zoo3==2.8.0a1) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.8.0a0->sb3_contrib<3.0,>=2.8.0a0->rl_zoo3==2.8.0a1) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.8.0a0->sb3_contrib<3.0,>=2.8.0a0->rl_zoo3==2.8.0a1) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.8.0a0->sb3_contrib<3.0,>=2.8.0a0->rl_zoo3==2.8.0a1) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.8.0a0->sb3_contrib<3.0,>=2.8.0a0->rl_zoo3==2.8.0a1) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.8.0a0->sb3_contrib<3.0,>=2.8.0a0->rl_zoo3==2.8.0a1) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.8.0a0->sb3_contrib<3.0,>=2.8.0a0->rl_zoo3==2.8.0a1) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch<3.0,>=2.3->stable_baselines3<3.0,>=2.8.0a0->sb3_contrib<3.0,>=2.8.0a0->rl_zoo3==2.8.0a1) (1.4.0)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.12/dist-packages (from Mako->alembic>=1.5.0->optuna>=3.0->rl_zoo3==2.8.0a1) (3.0.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable_baselines3<3.0,>=2.8.0a0->sb3_contrib<3.0,>=2.8.0a0->rl_zoo3==2.8.0a1) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable_baselines3<3.0,>=2.8.0a0->sb3_contrib<3.0,>=2.8.0a0->rl_zoo3==2.8.0a1) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable_baselines3<3.0,>=2.8.0a0->sb3_contrib<3.0,>=2.8.0a0->rl_zoo3==2.8.0a1) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable_baselines3<3.0,>=2.8.0a0->sb3_contrib<3.0,>=2.8.0a0->rl_zoo3==2.8.0a1) (1.4.9)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable_baselines3<3.0,>=2.8.0a0->sb3_contrib<3.0,>=2.8.0a0->rl_zoo3==2.8.0a1) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable_baselines3<3.0,>=2.8.0a0->sb3_contrib<3.0,>=2.8.0a0->rl_zoo3==2.8.0a1) (3.3.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->stable_baselines3<3.0,>=2.8.0a0->sb3_contrib<3.0,>=2.8.0a0->rl_zoo3==2.8.0a1) (2025.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub~=0.8->huggingface_sb3<4.0,>=3.0->rl_zoo3==2.8.0a1) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub~=0.8->huggingface_sb3<4.0,>=3.0->rl_zoo3==2.8.0a1) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub~=0.8->huggingface_sb3<4.0,>=3.0->rl_zoo3==2.8.0a1) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub~=0.8->huggingface_sb3<4.0,>=3.0->rl_zoo3==2.8.0a1) (2026.2.25)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch<3.0,>=2.3->stable_baselines3<3.0,>=2.8.0a0->sb3_contrib<3.0,>=2.8.0a0->rl_zoo3==2.8.0a1) (1.3.0)
# Downloading huggingface_sb3-3.0-py3-none-any.whl (9.7 kB)
# Downloading optuna-4.7.0-py3-none-any.whl (413 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 413.9/413.9 kB 41.0 MB/s eta 0:00:00
# Downloading pytablewriter-1.2.1-py3-none-any.whl (91 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.1/91.1 kB 12.8 MB/s eta 0:00:00
# Downloading sb3_contrib-2.8.0a0-py3-none-any.whl (92 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.0/93.0 kB 12.7 MB/s eta 0:00:00
# Downloading Shimmy-2.0.0-py3-none-any.whl (30 kB)
# Downloading DataProperty-1.1.0-py3-none-any.whl (27 kB)
# Downloading huggingface_hub-0.36.2-py3-none-any.whl (566 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 566.4/566.4 kB 54.3 MB/s eta 0:00:00
# Downloading mbstrdecoder-1.1.4-py3-none-any.whl (7.9 kB)
# Downloading pathvalidate-3.3.1-py3-none-any.whl (24 kB)
# Downloading stable_baselines3-2.8.0a2-py3-none-any.whl (187 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 187.3/187.3 kB 24.9 MB/s eta 0:00:00
# Downloading tabledata-1.3.4-py3-none-any.whl (11 kB)
# Downloading tcolorpy-0.1.7-py3-none-any.whl (8.1 kB)
# Downloading typepy-1.3.4-py3-none-any.whl (31 kB)
# Downloading colorlog-6.10.1-py3-none-any.whl (11 kB)
# Building wheels for collected packages: rl_zoo3
#   Building wheel for rl_zoo3 (pyproject.toml) ... done
#   Created wheel for rl_zoo3: filename=rl_zoo3-2.8.0a1-py3-none-any.whl size=78252 sha256=eb2040cf27eed062f340c8733f3a796e8b63e42b821d1086c35904c4c644f648
#   Stored in directory: /tmp/pip-ephem-wheel-cache-zqzcillj/wheels/cd/09/5b/8130538724a187021e02afe53ce7a1269c516a78a487a1ba15
# Successfully built rl_zoo3
# Installing collected packages: tcolorpy, pathvalidate, mbstrdecoder, colorlog, typepy, shimmy, huggingface-hub, optuna, huggingface_sb3, stable_baselines3, DataProperty, tabledata, sb3_contrib, pytablewriter, rl_zoo3
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface_hub 1.5.0
#     Uninstalling huggingface_hub-1.5.0:
#       Successfully uninstalled huggingface_hub-1.5.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# transformers 5.0.0 requires huggingface-hub<2.0,>=1.3.0, but you have huggingface-hub 0.36.2 which is incompatible.
# Successfully installed DataProperty-1.1.0 colorlog-6.10.1 huggingface-hub-0.36.2 huggingface_sb3-3.0 mbstrdecoder-1.1.4 optuna-4.7.0 pathvalidate-3.3.1 pytablewriter-1.2.1 rl_zoo3-2.8.0a1 sb3_contrib-2.8.0a0 shimmy-2.0.0 stable_baselines3-2.8.0a2 tabledata-1.3.4 tcolorpy-0.1.7 typepy-1.3.4

# %%
# !apt-get install swig cmake ffmpeg
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# cmake is already the newest version (3.22.1-1ubuntu1.22.04.2).
# ffmpeg is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# The following additional packages will be installed:
#   swig4.0
# Suggested packages:
#   swig-doc swig-examples swig4.0-examples swig4.0-doc
# The following NEW packages will be installed:
#   swig swig4.0
# 0 upgraded, 2 newly installed, 0 to remove and 37 not upgraded.
# Need to get 1,116 kB of archives.
# After this operation, 5,542 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 swig4.0 amd64 4.0.2-1ubuntu1 [1,110 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/universe amd64 swig all 4.0.2-1ubuntu1 [5,632 B]
# Fetched 1,116 kB in 2s (491 kB/s)
# Selecting previously unselected package swig4.0.
# (Reading database ... 121852 files and directories currently installed.)
# Preparing to unpack .../swig4.0_4.0.2-1ubuntu1_amd64.deb ...
# Unpacking swig4.0 (4.0.2-1ubuntu1) ...
# Selecting previously unselected package swig.
# Preparing to unpack .../swig_4.0.2-1ubuntu1_all.deb ...
# Unpacking swig (4.0.2-1ubuntu1) ...
# Setting up swig4.0 (4.0.2-1ubuntu1) ...
# Setting up swig (4.0.2-1ubuntu1) ...
# Processing triggers for man-db (2.10.2-1) ...

# %% [markdown]
# To be able to use Atari games in Gymnasium we need to install atari package. And accept-rom-license to download the rom files (games files).

# %%
# !pip install gymnasium[atari]
# !pip install gymnasium[accept-rom-license]
# Out:
# Requirement already satisfied: gymnasium[atari] in /usr/local/lib/python3.12/dist-packages (1.2.3)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium[atari]) (2.0.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium[atari]) (3.1.2)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium[atari]) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.12/dist-packages (from gymnasium[atari]) (0.0.4)
# Requirement already satisfied: ale_py>=0.9 in /usr/local/lib/python3.12/dist-packages (from gymnasium[atari]) (0.11.2)
# Requirement already satisfied: gymnasium[accept-rom-license] in /usr/local/lib/python3.12/dist-packages (1.2.3)
# WARNING: gymnasium 1.2.3 does not provide the extra 'accept-rom-license'
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium[accept-rom-license]) (2.0.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium[accept-rom-license]) (3.1.2)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium[accept-rom-license]) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.12/dist-packages (from gymnasium[accept-rom-license]) (0.0.4)

# %% [markdown]
# ## Create a virtual display 🔽
#
# During the notebook, we'll need to generate a replay video. To do so, with colab, **we need to have a virtual screen to be able to render the environment** (and thus record the frames).
#
# Hence the following cell will install the librairies and create and run a virtual screen 🖥

# %%
# %%capture
# !apt install python-opengl
# !apt install xvfb
# !pip3 install pyvirtualdisplay

# %%
# Virtual display
from pyvirtualdisplay import Display

virtual_display = Display(visible=0, size=(1400, 900))
virtual_display.start()

# %% [markdown]
# ## Train our Deep Q-Learning Agent to Play Space Invaders 👾
#
# To train an agent with RL-Baselines3-Zoo, we just need to do two things:
#
# 1. Create a hyperparameter config file that will contain our training hyperparameters called `dqn.yml`.
#
# This is a template example:
#
# ```
# SpaceInvadersNoFrameskip-v4:
#   env_wrapper:
#     - stable_baselines3.common.atari_wrappers.AtariWrapper
#   frame_stack: 4
#   policy: 'CnnPolicy'
#   n_timesteps: !!float 1e6
#   buffer_size: 100000
#   learning_rate: !!float 1e-4
#   batch_size: 32
#   learning_starts: 100000
#   target_update_interval: 1000
#   train_freq: 4
#   gradient_steps: 1
#   exploration_fraction: 0.1
#   exploration_final_eps: 0.01
#   # If True, you need to deactivate handle_timeout_termination
#   # in the replay_buffer_kwargs
#   optimize_memory_usage: False
# ```

# %% [markdown]
# Here we see that:
# - We use the `Atari Wrapper` that preprocess the input (Frame reduction ,grayscale, stack 4 frames)
# - We use `CnnPolicy`, since we use Convolutional layers to process the frames
# - We train it for 10 million `n_timesteps`
# - Memory (Experience Replay) size is 100000, aka the amount of experience steps you saved to train again your agent with.
#
# 💡 My advice is to **reduce the training timesteps to 1M,** which will take about 90 minutes on a P100. `!nvidia-smi` will tell you what GPU you're using. At 10 million steps, this will take about 9 hours, which could likely result in Colab timing out. I recommend running this on your local computer (or somewhere else). Just click on: `File>Download`.

# %% [markdown]
# In terms of hyperparameters optimization, my advice is to focus on these 3 hyperparameters:
# - `learning_rate`
# - `buffer_size (Experience Memory size)`
# - `batch_size`
#
# As a good practice, you need to **check the documentation to understand what each hyperparameters does**: https://stable-baselines3.readthedocs.io/en/master/modules/dqn.html#parameters

# %% [markdown]
# 2. We start the training and save the models on `logs` folder 📁
#
# - Define the algorithm after `--algo`, where we save the model after `-f` and where the hyperparameter config is after `-c`.

# %%
# !python -m rl_zoo3.train --algo dqn  --env SpaceInvadersNoFrameskip-v4 -f logs/ -c dqn.yaml
# Out:
# Streaming output truncated to the last 5000 lines.
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.1e+03  |
# |    ep_rew_mean      | 398      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2848     |
# |    fps              | 272      |
# |    time_elapsed     | 2146     |
# |    total_timesteps  | 584408   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.042    |
# |    n_updates        | 121101   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.1e+03  |
# |    ep_rew_mean      | 398      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2852     |
# |    fps              | 272      |
# |    time_elapsed     | 2150     |
# |    total_timesteps  | 585504   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0186   |
# |    n_updates        | 121375   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.1e+03  |
# |    ep_rew_mean      | 398      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2856     |
# |    fps              | 272      |
# |    time_elapsed     | 2153     |
# |    total_timesteps  | 586171   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0486   |
# |    n_updates        | 121542   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.12e+03 |
# |    ep_rew_mean      | 402      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2860     |
# |    fps              | 272      |
# |    time_elapsed     | 2158     |
# |    total_timesteps  | 587426   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0451   |
# |    n_updates        | 121856   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.12e+03 |
# |    ep_rew_mean      | 403      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2864     |
# |    fps              | 272      |
# |    time_elapsed     | 2161     |
# |    total_timesteps  | 588286   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0229   |
# |    n_updates        | 122071   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.11e+03 |
# |    ep_rew_mean      | 396      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2868     |
# |    fps              | 272      |
# |    time_elapsed     | 2164     |
# |    total_timesteps  | 589328   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0412   |
# |    n_updates        | 122331   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.08e+03 |
# |    ep_rew_mean      | 389      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2872     |
# |    fps              | 272      |
# |    time_elapsed     | 2167     |
# |    total_timesteps  | 589878   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0396   |
# |    n_updates        | 122469   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.09e+03 |
# |    ep_rew_mean      | 391      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2876     |
# |    fps              | 272      |
# |    time_elapsed     | 2170     |
# |    total_timesteps  | 590716   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0395   |
# |    n_updates        | 122678   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.08e+03 |
# |    ep_rew_mean      | 389      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2880     |
# |    fps              | 272      |
# |    time_elapsed     | 2174     |
# |    total_timesteps  | 591846   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0485   |
# |    n_updates        | 122961   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.07e+03 |
# |    ep_rew_mean      | 389      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2884     |
# |    fps              | 272      |
# |    time_elapsed     | 2180     |
# |    total_timesteps  | 593338   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.109    |
# |    n_updates        | 123334   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.1e+03  |
# |    ep_rew_mean      | 391      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2888     |
# |    fps              | 272      |
# |    time_elapsed     | 2184     |
# |    total_timesteps  | 594390   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.02     |
# |    n_updates        | 123597   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.1e+03  |
# |    ep_rew_mean      | 390      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2892     |
# |    fps              | 272      |
# |    time_elapsed     | 2187     |
# |    total_timesteps  | 595194   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0281   |
# |    n_updates        | 123798   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.08e+03 |
# |    ep_rew_mean      | 386      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2896     |
# |    fps              | 272      |
# |    time_elapsed     | 2191     |
# |    total_timesteps  | 596412   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00913  |
# |    n_updates        | 124102   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.08e+03 |
# |    ep_rew_mean      | 386      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2900     |
# |    fps              | 272      |
# |    time_elapsed     | 2195     |
# |    total_timesteps  | 597236   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0169   |
# |    n_updates        | 124308   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.08e+03 |
# |    ep_rew_mean      | 385      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2904     |
# |    fps              | 272      |
# |    time_elapsed     | 2199     |
# |    total_timesteps  | 598419   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0328   |
# |    n_updates        | 124604   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.1e+03  |
# |    ep_rew_mean      | 389      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2908     |
# |    fps              | 272      |
# |    time_elapsed     | 2204     |
# |    total_timesteps  | 599690   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0383   |
# |    n_updates        | 124922   |
# ----------------------------------
# Eval num_timesteps=600000, episode_reward=388.00 +/- 208.92
# Episode length: 3065.80 +/- 910.96
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 3.07e+03 |
# |    mean_reward      | 388      |
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    total_timesteps  | 600000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0428   |
# |    n_updates        | 124999   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.12e+03 |
# |    ep_rew_mean      | 390      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2912     |
# |    fps              | 271      |
# |    time_elapsed     | 2215     |
# |    total_timesteps  | 600672   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0443   |
# |    n_updates        | 125167   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.12e+03 |
# |    ep_rew_mean      | 392      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2916     |
# |    fps              | 271      |
# |    time_elapsed     | 2220     |
# |    total_timesteps  | 601774   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.044    |
# |    n_updates        | 125443   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.12e+03 |
# |    ep_rew_mean      | 393      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2920     |
# |    fps              | 271      |
# |    time_elapsed     | 2223     |
# |    total_timesteps  | 602660   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0473   |
# |    n_updates        | 125664   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.11e+03 |
# |    ep_rew_mean      | 392      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2924     |
# |    fps              | 271      |
# |    time_elapsed     | 2226     |
# |    total_timesteps  | 603674   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0123   |
# |    n_updates        | 125918   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.12e+03 |
# |    ep_rew_mean      | 395      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2928     |
# |    fps              | 271      |
# |    time_elapsed     | 2231     |
# |    total_timesteps  | 604738   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0287   |
# |    n_updates        | 126184   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.11e+03 |
# |    ep_rew_mean      | 395      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2932     |
# |    fps              | 271      |
# |    time_elapsed     | 2233     |
# |    total_timesteps  | 605490   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0145   |
# |    n_updates        | 126372   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.1e+03  |
# |    ep_rew_mean      | 392      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2936     |
# |    fps              | 271      |
# |    time_elapsed     | 2238     |
# |    total_timesteps  | 606895   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0115   |
# |    n_updates        | 126723   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.08e+03 |
# |    ep_rew_mean      | 383      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2940     |
# |    fps              | 271      |
# |    time_elapsed     | 2242     |
# |    total_timesteps  | 607603   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0461   |
# |    n_updates        | 126900   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.08e+03 |
# |    ep_rew_mean      | 383      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2944     |
# |    fps              | 271      |
# |    time_elapsed     | 2246     |
# |    total_timesteps  | 608712   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0375   |
# |    n_updates        | 127177   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.08e+03 |
# |    ep_rew_mean      | 386      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2948     |
# |    fps              | 271      |
# |    time_elapsed     | 2249     |
# |    total_timesteps  | 609835   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0178   |
# |    n_updates        | 127458   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.11e+03 |
# |    ep_rew_mean      | 384      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2952     |
# |    fps              | 270      |
# |    time_elapsed     | 2254     |
# |    total_timesteps  | 611079   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.032    |
# |    n_updates        | 127769   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.12e+03 |
# |    ep_rew_mean      | 386      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2956     |
# |    fps              | 271      |
# |    time_elapsed     | 2258     |
# |    total_timesteps  | 612063   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.05     |
# |    n_updates        | 128015   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.13e+03 |
# |    ep_rew_mean      | 388      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2960     |
# |    fps              | 271      |
# |    time_elapsed     | 2263     |
# |    total_timesteps  | 613344   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0169   |
# |    n_updates        | 128335   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.13e+03 |
# |    ep_rew_mean      | 386      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2964     |
# |    fps              | 270      |
# |    time_elapsed     | 2266     |
# |    total_timesteps  | 614248   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0215   |
# |    n_updates        | 128561   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.15e+03 |
# |    ep_rew_mean      | 387      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2968     |
# |    fps              | 270      |
# |    time_elapsed     | 2272     |
# |    total_timesteps  | 615852   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0207   |
# |    n_updates        | 128962   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.14e+03 |
# |    ep_rew_mean      | 385      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2972     |
# |    fps              | 271      |
# |    time_elapsed     | 2276     |
# |    total_timesteps  | 616926   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0211   |
# |    n_updates        | 129231   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.15e+03 |
# |    ep_rew_mean      | 387      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2976     |
# |    fps              | 270      |
# |    time_elapsed     | 2280     |
# |    total_timesteps  | 618028   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0482   |
# |    n_updates        | 129506   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.15e+03 |
# |    ep_rew_mean      | 390      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2980     |
# |    fps              | 270      |
# |    time_elapsed     | 2285     |
# |    total_timesteps  | 619377   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0132   |
# |    n_updates        | 129844   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.17e+03 |
# |    ep_rew_mean      | 392      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2984     |
# |    fps              | 271      |
# |    time_elapsed     | 2288     |
# |    total_timesteps  | 620125   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0204   |
# |    n_updates        | 130031   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.18e+03 |
# |    ep_rew_mean      | 394      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2988     |
# |    fps              | 270      |
# |    time_elapsed     | 2293     |
# |    total_timesteps  | 621480   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0262   |
# |    n_updates        | 130369   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.18e+03 |
# |    ep_rew_mean      | 396      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2992     |
# |    fps              | 270      |
# |    time_elapsed     | 2297     |
# |    total_timesteps  | 622700   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0272   |
# |    n_updates        | 130674   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.18e+03 |
# |    ep_rew_mean      | 396      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2996     |
# |    fps              | 271      |
# |    time_elapsed     | 2301     |
# |    total_timesteps  | 623625   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0294   |
# |    n_updates        | 130906   |
# ----------------------------------
# Eval num_timesteps=625000, episode_reward=580.00 +/- 147.55
# Episode length: 3696.20 +/- 709.50
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 3.7e+03  |
# |    mean_reward      | 580      |
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    total_timesteps  | 625000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.107    |
# |    n_updates        | 131249   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.19e+03 |
# |    ep_rew_mean      | 398      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3000     |
# |    fps              | 269      |
# |    time_elapsed     | 2316     |
# |    total_timesteps  | 625032   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0277   |
# |    n_updates        | 131257   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.2e+03  |
# |    ep_rew_mean      | 403      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3004     |
# |    fps              | 269      |
# |    time_elapsed     | 2321     |
# |    total_timesteps  | 626293   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0443   |
# |    n_updates        | 131573   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.2e+03  |
# |    ep_rew_mean      | 404      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3008     |
# |    fps              | 269      |
# |    time_elapsed     | 2325     |
# |    total_timesteps  | 627417   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0481   |
# |    n_updates        | 131854   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.19e+03 |
# |    ep_rew_mean      | 400      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3012     |
# |    fps              | 269      |
# |    time_elapsed     | 2329     |
# |    total_timesteps  | 628528   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0326   |
# |    n_updates        | 132131   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.18e+03 |
# |    ep_rew_mean      | 401      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3016     |
# |    fps              | 269      |
# |    time_elapsed     | 2333     |
# |    total_timesteps  | 629600   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0133   |
# |    n_updates        | 132399   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.2e+03  |
# |    ep_rew_mean      | 407      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3020     |
# |    fps              | 269      |
# |    time_elapsed     | 2337     |
# |    total_timesteps  | 630850   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0117   |
# |    n_updates        | 132712   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.2e+03  |
# |    ep_rew_mean      | 407      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3024     |
# |    fps              | 269      |
# |    time_elapsed     | 2341     |
# |    total_timesteps  | 631802   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0718   |
# |    n_updates        | 132950   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.2e+03  |
# |    ep_rew_mean      | 409      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3028     |
# |    fps              | 269      |
# |    time_elapsed     | 2345     |
# |    total_timesteps  | 632755   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0172   |
# |    n_updates        | 133188   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.2e+03  |
# |    ep_rew_mean      | 411      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3032     |
# |    fps              | 269      |
# |    time_elapsed     | 2350     |
# |    total_timesteps  | 634136   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0269   |
# |    n_updates        | 133533   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.21e+03 |
# |    ep_rew_mean      | 412      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3036     |
# |    fps              | 269      |
# |    time_elapsed     | 2354     |
# |    total_timesteps  | 635149   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.046    |
# |    n_updates        | 133787   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.22e+03 |
# |    ep_rew_mean      | 418      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3040     |
# |    fps              | 269      |
# |    time_elapsed     | 2358     |
# |    total_timesteps  | 636437   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.042    |
# |    n_updates        | 134109   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.23e+03 |
# |    ep_rew_mean      | 419      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3044     |
# |    fps              | 269      |
# |    time_elapsed     | 2362     |
# |    total_timesteps  | 637443   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.066    |
# |    n_updates        | 134360   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.22e+03 |
# |    ep_rew_mean      | 419      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3048     |
# |    fps              | 269      |
# |    time_elapsed     | 2366     |
# |    total_timesteps  | 638547   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0267   |
# |    n_updates        | 134636   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.22e+03 |
# |    ep_rew_mean      | 419      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3052     |
# |    fps              | 269      |
# |    time_elapsed     | 2370     |
# |    total_timesteps  | 639628   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0299   |
# |    n_updates        | 134906   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.23e+03 |
# |    ep_rew_mean      | 420      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3056     |
# |    fps              | 269      |
# |    time_elapsed     | 2374     |
# |    total_timesteps  | 640799   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0301   |
# |    n_updates        | 135199   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.23e+03 |
# |    ep_rew_mean      | 424      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3060     |
# |    fps              | 269      |
# |    time_elapsed     | 2378     |
# |    total_timesteps  | 641557   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0253   |
# |    n_updates        | 135389   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.22e+03 |
# |    ep_rew_mean      | 420      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3064     |
# |    fps              | 269      |
# |    time_elapsed     | 2382     |
# |    total_timesteps  | 642833   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0338   |
# |    n_updates        | 135708   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.23e+03 |
# |    ep_rew_mean      | 421      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3068     |
# |    fps              | 269      |
# |    time_elapsed     | 2385     |
# |    total_timesteps  | 643574   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0209   |
# |    n_updates        | 135893   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.21e+03 |
# |    ep_rew_mean      | 420      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3072     |
# |    fps              | 269      |
# |    time_elapsed     | 2392     |
# |    total_timesteps  | 645575   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0294   |
# |    n_updates        | 136393   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.22e+03 |
# |    ep_rew_mean      | 421      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3076     |
# |    fps              | 269      |
# |    time_elapsed     | 2396     |
# |    total_timesteps  | 646565   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0314   |
# |    n_updates        | 136641   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.23e+03 |
# |    ep_rew_mean      | 426      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3080     |
# |    fps              | 269      |
# |    time_elapsed     | 2401     |
# |    total_timesteps  | 648013   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0155   |
# |    n_updates        | 137003   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.24e+03 |
# |    ep_rew_mean      | 430      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3084     |
# |    fps              | 269      |
# |    time_elapsed     | 2407     |
# |    total_timesteps  | 649427   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0306   |
# |    n_updates        | 137356   |
# ----------------------------------
# Eval num_timesteps=650000, episode_reward=366.00 +/- 67.63
# Episode length: 3348.80 +/- 504.98
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 3.35e+03 |
# |    mean_reward      | 366      |
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    total_timesteps  | 650000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0298   |
# |    n_updates        | 137499   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.24e+03 |
# |    ep_rew_mean      | 429      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3088     |
# |    fps              | 268      |
# |    time_elapsed     | 2419     |
# |    total_timesteps  | 650302   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0141   |
# |    n_updates        | 137575   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.23e+03 |
# |    ep_rew_mean      | 430      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3092     |
# |    fps              | 268      |
# |    time_elapsed     | 2423     |
# |    total_timesteps  | 651485   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0271   |
# |    n_updates        | 137871   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.27e+03 |
# |    ep_rew_mean      | 435      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3096     |
# |    fps              | 268      |
# |    time_elapsed     | 2430     |
# |    total_timesteps  | 653357   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0411   |
# |    n_updates        | 138339   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.27e+03 |
# |    ep_rew_mean      | 436      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3100     |
# |    fps              | 268      |
# |    time_elapsed     | 2435     |
# |    total_timesteps  | 654491   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0104   |
# |    n_updates        | 138622   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.27e+03 |
# |    ep_rew_mean      | 438      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3104     |
# |    fps              | 268      |
# |    time_elapsed     | 2439     |
# |    total_timesteps  | 655606   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0199   |
# |    n_updates        | 138901   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.27e+03 |
# |    ep_rew_mean      | 436      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3108     |
# |    fps              | 268      |
# |    time_elapsed     | 2442     |
# |    total_timesteps  | 656349   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0293   |
# |    n_updates        | 139087   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.25e+03 |
# |    ep_rew_mean      | 432      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3112     |
# |    fps              | 268      |
# |    time_elapsed     | 2445     |
# |    total_timesteps  | 657310   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0436   |
# |    n_updates        | 139327   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.27e+03 |
# |    ep_rew_mean      | 435      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3116     |
# |    fps              | 268      |
# |    time_elapsed     | 2450     |
# |    total_timesteps  | 658688   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0264   |
# |    n_updates        | 139671   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.28e+03 |
# |    ep_rew_mean      | 435      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3120     |
# |    fps              | 268      |
# |    time_elapsed     | 2456     |
# |    total_timesteps  | 660233   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0389   |
# |    n_updates        | 140058   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.32e+03 |
# |    ep_rew_mean      | 441      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3124     |
# |    fps              | 268      |
# |    time_elapsed     | 2463     |
# |    total_timesteps  | 662082   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0468   |
# |    n_updates        | 140520   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.33e+03 |
# |    ep_rew_mean      | 444      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3128     |
# |    fps              | 268      |
# |    time_elapsed     | 2467     |
# |    total_timesteps  | 663022   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0387   |
# |    n_updates        | 140755   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.33e+03 |
# |    ep_rew_mean      | 445      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3132     |
# |    fps              | 268      |
# |    time_elapsed     | 2470     |
# |    total_timesteps  | 664113   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0393   |
# |    n_updates        | 141028   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.33e+03 |
# |    ep_rew_mean      | 443      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3136     |
# |    fps              | 268      |
# |    time_elapsed     | 2475     |
# |    total_timesteps  | 665321   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00689  |
# |    n_updates        | 141330   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.34e+03 |
# |    ep_rew_mean      | 448      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3140     |
# |    fps              | 268      |
# |    time_elapsed     | 2480     |
# |    total_timesteps  | 666583   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0671   |
# |    n_updates        | 141645   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.34e+03 |
# |    ep_rew_mean      | 446      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3144     |
# |    fps              | 268      |
# |    time_elapsed     | 2483     |
# |    total_timesteps  | 667508   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0113   |
# |    n_updates        | 141876   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.35e+03 |
# |    ep_rew_mean      | 445      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3148     |
# |    fps              | 268      |
# |    time_elapsed     | 2488     |
# |    total_timesteps  | 668765   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0115   |
# |    n_updates        | 142191   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.36e+03 |
# |    ep_rew_mean      | 446      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3152     |
# |    fps              | 268      |
# |    time_elapsed     | 2493     |
# |    total_timesteps  | 670139   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0133   |
# |    n_updates        | 142534   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.35e+03 |
# |    ep_rew_mean      | 444      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3156     |
# |    fps              | 268      |
# |    time_elapsed     | 2496     |
# |    total_timesteps  | 670962   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0329   |
# |    n_updates        | 142740   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.36e+03 |
# |    ep_rew_mean      | 445      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3160     |
# |    fps              | 268      |
# |    time_elapsed     | 2501     |
# |    total_timesteps  | 672157   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0146   |
# |    n_updates        | 143039   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.38e+03 |
# |    ep_rew_mean      | 447      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3164     |
# |    fps              | 268      |
# |    time_elapsed     | 2504     |
# |    total_timesteps  | 673110   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0199   |
# |    n_updates        | 143277   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.38e+03 |
# |    ep_rew_mean      | 448      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3168     |
# |    fps              | 268      |
# |    time_elapsed     | 2509     |
# |    total_timesteps  | 674306   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0479   |
# |    n_updates        | 143576   |
# ----------------------------------
# Eval num_timesteps=675000, episode_reward=467.00 +/- 114.13
# Episode length: 3657.60 +/- 524.16
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 3.66e+03 |
# |    mean_reward      | 467      |
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    total_timesteps  | 675000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0229   |
# |    n_updates        | 143749   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.38e+03 |
# |    ep_rew_mean      | 448      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3172     |
# |    fps              | 267      |
# |    time_elapsed     | 2523     |
# |    total_timesteps  | 675566   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0188   |
# |    n_updates        | 143891   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.39e+03 |
# |    ep_rew_mean      | 450      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3176     |
# |    fps              | 267      |
# |    time_elapsed     | 2528     |
# |    total_timesteps  | 676862   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0155   |
# |    n_updates        | 144215   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.39e+03 |
# |    ep_rew_mean      | 452      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3180     |
# |    fps              | 267      |
# |    time_elapsed     | 2532     |
# |    total_timesteps  | 677931   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0326   |
# |    n_updates        | 144482   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.39e+03 |
# |    ep_rew_mean      | 455      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3184     |
# |    fps              | 267      |
# |    time_elapsed     | 2535     |
# |    total_timesteps  | 678844   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0381   |
# |    n_updates        | 144710   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.39e+03 |
# |    ep_rew_mean      | 456      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3188     |
# |    fps              | 267      |
# |    time_elapsed     | 2539     |
# |    total_timesteps  | 679666   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0151   |
# |    n_updates        | 144916   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.37e+03 |
# |    ep_rew_mean      | 450      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3192     |
# |    fps              | 267      |
# |    time_elapsed     | 2541     |
# |    total_timesteps  | 680276   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0148   |
# |    n_updates        | 145068   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# ...
# |    loss             | 0.0166   |
# |    n_updates        | 213843   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.08e+03 |
# |    ep_rew_mean      | 590      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4000     |
# |    fps              | 260      |
# |    time_elapsed     | 3679     |
# |    total_timesteps  | 956726   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0148   |
# |    n_updates        | 214181   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.06e+03 |
# |    ep_rew_mean      | 587      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4004     |
# |    fps              | 260      |
# |    time_elapsed     | 3682     |
# |    total_timesteps  | 957609   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0168   |
# |    n_updates        | 214402   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.06e+03 |
# |    ep_rew_mean      | 584      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4008     |
# |    fps              | 260      |
# |    time_elapsed     | 3689     |
# |    total_timesteps  | 959314   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0168   |
# |    n_updates        | 214828   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.03e+03 |
# |    ep_rew_mean      | 580      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4012     |
# |    fps              | 260      |
# |    time_elapsed     | 3691     |
# |    total_timesteps  | 960030   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0146   |
# |    n_updates        | 215007   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.05e+03 |
# |    ep_rew_mean      | 585      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4016     |
# |    fps              | 260      |
# |    time_elapsed     | 3698     |
# |    total_timesteps  | 961853   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0149   |
# |    n_updates        | 215463   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.06e+03 |
# |    ep_rew_mean      | 585      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4020     |
# |    fps              | 260      |
# |    time_elapsed     | 3704     |
# |    total_timesteps  | 963482   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0253   |
# |    n_updates        | 215870   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.08e+03 |
# |    ep_rew_mean      | 588      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4024     |
# |    fps              | 260      |
# |    time_elapsed     | 3710     |
# |    total_timesteps  | 965249   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0331   |
# |    n_updates        | 216312   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.07e+03 |
# |    ep_rew_mean      | 587      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4028     |
# |    fps              | 260      |
# |    time_elapsed     | 3716     |
# |    total_timesteps  | 966722   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0312   |
# |    n_updates        | 216680   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.1e+03  |
# |    ep_rew_mean      | 596      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4032     |
# |    fps              | 260      |
# |    time_elapsed     | 3725     |
# |    total_timesteps  | 969133   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0141   |
# |    n_updates        | 217283   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.13e+03 |
# |    ep_rew_mean      | 601      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4036     |
# |    fps              | 260      |
# |    time_elapsed     | 3732     |
# |    total_timesteps  | 971003   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0485   |
# |    n_updates        | 217750   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.13e+03 |
# |    ep_rew_mean      | 600      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4040     |
# |    fps              | 260      |
# |    time_elapsed     | 3741     |
# |    total_timesteps  | 973566   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0474   |
# |    n_updates        | 218391   |
# ----------------------------------
# Eval num_timesteps=975000, episode_reward=734.00 +/- 412.40
# Episode length: 5029.80 +/- 1752.00
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 5.03e+03 |
# |    mean_reward      | 734      |
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    total_timesteps  | 975000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0288   |
# |    n_updates        | 218749   |
# ----------------------------------
# New best mean reward!
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.17e+03 |
# |    ep_rew_mean      | 611      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4044     |
# |    fps              | 259      |
# |    time_elapsed     | 3761     |
# |    total_timesteps  | 975366   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0279   |
# |    n_updates        | 218841   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.2e+03  |
# |    ep_rew_mean      | 615      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4048     |
# |    fps              | 259      |
# |    time_elapsed     | 3768     |
# |    total_timesteps  | 977177   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0153   |
# |    n_updates        | 219294   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.22e+03 |
# |    ep_rew_mean      | 613      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4052     |
# |    fps              | 259      |
# |    time_elapsed     | 3773     |
# |    total_timesteps  | 978624   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0146   |
# |    n_updates        | 219655   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.18e+03 |
# |    ep_rew_mean      | 610      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4056     |
# |    fps              | 259      |
# |    time_elapsed     | 3776     |
# |    total_timesteps  | 979506   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0143   |
# |    n_updates        | 219876   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.18e+03 |
# |    ep_rew_mean      | 606      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4060     |
# |    fps              | 259      |
# |    time_elapsed     | 3784     |
# |    total_timesteps  | 981422   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0158   |
# |    n_updates        | 220355   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.2e+03  |
# |    ep_rew_mean      | 612      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4064     |
# |    fps              | 259      |
# |    time_elapsed     | 3787     |
# |    total_timesteps  | 982456   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0343   |
# |    n_updates        | 220613   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.19e+03 |
# |    ep_rew_mean      | 614      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4068     |
# |    fps              | 259      |
# |    time_elapsed     | 3794     |
# |    total_timesteps  | 984356   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00919  |
# |    n_updates        | 221088   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.18e+03 |
# |    ep_rew_mean      | 615      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4072     |
# |    fps              | 259      |
# |    time_elapsed     | 3799     |
# |    total_timesteps  | 985705   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0154   |
# |    n_updates        | 221426   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.17e+03 |
# |    ep_rew_mean      | 612      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4076     |
# |    fps              | 259      |
# |    time_elapsed     | 3803     |
# |    total_timesteps  | 986827   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0412   |
# |    n_updates        | 221706   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.14e+03 |
# |    ep_rew_mean      | 604      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4080     |
# |    fps              | 259      |
# |    time_elapsed     | 3812     |
# |    total_timesteps  | 989219   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0566   |
# |    n_updates        | 222304   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.14e+03 |
# |    ep_rew_mean      | 606      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4084     |
# |    fps              | 259      |
# |    time_elapsed     | 3816     |
# |    total_timesteps  | 990282   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0192   |
# |    n_updates        | 222570   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.15e+03 |
# |    ep_rew_mean      | 606      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4088     |
# |    fps              | 259      |
# |    time_elapsed     | 3823     |
# |    total_timesteps  | 992131   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0287   |
# |    n_updates        | 223032   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.15e+03 |
# |    ep_rew_mean      | 606      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4092     |
# |    fps              | 259      |
# |    time_elapsed     | 3827     |
# |    total_timesteps  | 993377   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0189   |
# |    n_updates        | 223344   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.14e+03 |
# |    ep_rew_mean      | 603      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4096     |
# |    fps              | 259      |
# |    time_elapsed     | 3833     |
# |    total_timesteps  | 994908   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0307   |
# |    n_updates        | 223726   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.15e+03 |
# |    ep_rew_mean      | 604      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4100     |
# |    fps              | 259      |
# |    time_elapsed     | 3837     |
# |    total_timesteps  | 996171   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0264   |
# |    n_updates        | 224042   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.15e+03 |
# |    ep_rew_mean      | 603      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4104     |
# |    fps              | 259      |
# |    time_elapsed     | 3841     |
# |    total_timesteps  | 997110   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0225   |
# |    n_updates        | 224277   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.16e+03 |
# |    ep_rew_mean      | 603      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4108     |
# |    fps              | 259      |
# |    time_elapsed     | 3846     |
# |    total_timesteps  | 998556   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0232   |
# |    n_updates        | 224638   |
# ----------------------------------
# Eval num_timesteps=1000000, episode_reward=419.00 +/- 190.67
# Episode length: 3075.60 +/- 773.92
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 3.08e+03 |
# |    mean_reward      | 419      |
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    total_timesteps  | 1000000  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.015    |
# |    n_updates        | 224999   |
# ----------------------------------
# Saving to logs//dqn/SpaceInvadersNoFrameskip-v4_1

# %% [markdown]
# ## Let's evaluate our agent 👀
# - RL-Baselines3-Zoo provides `enjoy.py`, a python script to evaluate our agent. In most RL libraries, we call the evaluation script `enjoy.py`.
# - Let's evaluate it for 5000 timesteps 🔥

# %%
# !python -m rl_zoo3.enjoy  --algo dqn  --env SpaceInvadersNoFrameskip-v4  --no-render  --n-timesteps 5000  --folder logs/
# Out:
# 2026-03-05 08:49:07.041446: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1772700547.073389   21788 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1772700547.080405   21788 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1772700547.097910   21788 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1772700547.097935   21788 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1772700547.097939   21788 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1772700547.097942   21788 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-03-05 08:49:07.102249: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.
# Loading latest experiment, id=1
# Loading logs/dqn/SpaceInvadersNoFrameskip-v4_1/SpaceInvadersNoFrameskip-v4.zip
# A.L.E: Arcade Learning Environment (version 0.11.2+ecc1138)
# [Powered by Stella]
# Stacking 4 frames
# Atari Episode Score: 525.00
# Atari Episode Length 3001
# Atari Episode Score: 445.00
# Atari Episode Length 2979
# Atari Episode Score: 570.00
# Atari Episode Length 3924
# Atari Episode Score: 525.00
# Atari Episode Length 3001
# Atari Episode Score: 410.00
# Atari Episode Length 3629

# %% [markdown]
# ## Publish our trained model on the Hub 🚀
# Now that we saw we got good results after the training, we can publish our trained model on the hub 🤗 with one line of code.
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/unit3/space-invaders-model.gif" alt="Space Invaders model">

# %% [markdown]
# By using `rl_zoo3.push_to_hub` **you evaluate, record a replay, generate a model card of your agent and push it to the hub**.
#
# This way:
# - You can **showcase our work** 🔥
# - You can **visualize your agent playing** 👀
# - You can **share with the community an agent that others can use** 💾
# - You can **access a leaderboard 🏆 to see how well your agent is performing compared to your classmates** 👉  https://huggingface.co/spaces/huggingface-projects/Deep-Reinforcement-Learning-Leaderboard

# %% [markdown]
# To be able to share your model with the community there are three more steps to follow:
#
# 1️⃣ (If it's not already done) create an account to HF ➡ https://huggingface.co/join
#
# 2️⃣ Sign in and then, you need to store your authentication token from the Hugging Face website.
# - Create a new token (https://huggingface.co/settings/tokens) **with write role**
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/create-token.jpg" alt="Create HF Token">

# %% [markdown]
# - Copy the token
# - Run the cell below and past the token

# %%
from huggingface_hub import notebook_login # To log to our Hugging Face account to be able to upload models to the Hub.
notebook_login()
# !git config --global credential.helper store
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %% [markdown]
# If you don't want to use a Google Colab or a Jupyter Notebook, you need to use this command instead: `huggingface-cli login`

# %% [markdown]
# 3️⃣ We're now ready to push our trained agent to the 🤗 Hub 🔥

# %% [markdown]
# Let's run push_to_hub.py file to upload our trained agent to the Hub.
#
# `--repo-name `: The name of the repo
#
# `-orga`: Your Hugging Face username
#
# `-f`: Where the trained model folder is (in our case `logs`)

# %%
# !python -m rl_zoo3.push_to_hub  --algo dqn  --env SpaceInvadersNoFrameskip-v4  --repo-name dqn-SpaceInvadersNoFrameskip-v4  -orga KraTUZen -f logs/
# Out:
# 2026-03-05 08:49:30.587480: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1772700570.608043   21905 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1772700570.614908   21905 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1772700570.632309   21905 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1772700570.632334   21905 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1772700570.632338   21905 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1772700570.632341   21905 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-03-05 08:49:30.636799: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.
# Loading latest experiment, id=1
# Loading logs/dqn/SpaceInvadersNoFrameskip-v4_1/SpaceInvadersNoFrameskip-v4.zip
# A.L.E: Arcade Learning Environment (version 0.11.2+ecc1138)
# [Powered by Stella]
# Stacking 4 frames
# Wrapping the env in a VecTransposeImage.
# Uploading to KraTUZen/dqn-SpaceInvadersNoFrameskip-v4, make sure to have the rights
# ℹ This function will save, evaluate, generate a video of your agent,
# create a model card and push everything to the hub. It might take up to some
# minutes if video generation is activated. This is a work in progress: if you
# encounter a bug, please open an issue.
# Fetching 1 files:   0% 0/1 [00:00<?, ?it/s]
# .gitattributes: 1.52kB [00:00, 3.54MB/s]
# Fetching 1 files: 100% 1/1 [00:00<00:00,  1.34it/s]
# Saving model to: hub/dqn-SpaceInvadersNoFrameskip-v4/dqn-SpaceInvadersNoFrameskip-v4
# Saving video to /tmp/tmp95fcs6u7/-step-0-to-step-1000.mp4
# /usr/local/lib/python3.12/dist-packages/moviepy/config_defaults.py:47: SyntaxWarning: invalid escape sequence '\P'
#   IMAGEMAGICK_BINARY = r"C:\Program Files\ImageMagick-6.8.8-Q16\magick.exe"
# Moviepy - Building video /tmp/tmp95fcs6u7/-step-0-to-step-1000.mp4.
# Moviepy - Writing video /tmp/tmp95fcs6u7/-step-0-to-step-1000.mp4
#
# Moviepy - Done !
# Moviepy - video ready /tmp/tmp95fcs6u7/-step-0-to-step-1000.mp4
# ✘ 'DummyVecEnv' object has no attribute 'video_recorder'
# ✘ We are unable to generate a replay of your agent, the package_to_hub
# process continues
# ✘ Please open an issue at
# https://github.com/huggingface/huggingface_sb3/issues
# ℹ Pushing repo dqn-SpaceInvadersNoFrameskip-v4 to the Hugging Face
# Hub
# Processing Files (0 / 0)      : |          |  0.00B /  0.00B
# New Data Upload               : |          |  0.00B /  0.00B
#
#   ...-v4/pytorch_variables.pth: 100% 1.26k/1.26k [00:00<?, ?B/s]
#
# Processing Files (1 / 1)      :   0% 1.26k/54.3M [00:01<12:07:36, 1.24kB/s, 1.58kB/s  ]
#
#   ...-v4/pytorch_variables.pth: 100% 1.26k/1.26k [00:00<?, ?B/s]
#
#   ...-v4/pytorch_variables.pth: 100% 1.26k/1.26k [00:00<?, ?B/s]
#
#
#   ...p-v4/policy.optimizer.pth:   2% 211k/13.5M [00:00<?, ?B/s]
#
#
#
#   ...NoFrameskip-v4/policy.pth:   2% 211k/13.5M [00:00<?, ?B/s]
#
#
#
#
#   ...nvadersNoFrameskip-v4.zip:   2% 426k/27.2M [00:00<?, ?B/s]
#
#
#
#
#
#   ...v4/train_eval_metrics.zip:   2% 590/37.7k [00:00<?, ?B/s]
#
#   ...-v4/pytorch_variables.pth: 100% 1.26k/1.26k [00:00<?, ?B/s]
#
#
#   ...p-v4/policy.optimizer.pth:   2% 211k/13.5M [00:00<?, ?B/s]
#
#
#
#   ...NoFrameskip-v4/policy.pth:   2% 211k/13.5M [00:00<?, ?B/s]
#
#
#
#
#   ...nvadersNoFrameskip-v4.zip:   2% 426k/27.2M [00:00<?, ?B/s]
#
#
#
#
#
# Processing Files (1 / 5)      :   2% 850k/54.3M [00:01<01:22, 650kB/s,  607kB/s  ]
# New Data Upload               :   2% 826k/52.8M [00:01<01:41, 512kB/s,  590kB/s  ]
#
#   ...-v4/pytorch_variables.pth: 100% 1.26k/1.26k [00:00<?, ?B/s]
#
#
#   ...p-v4/policy.optimizer.pth:   2% 211k/13.5M [00:00<?, ?B/s]
#
#
#
#   ...NoFrameskip-v4/policy.pth:   2% 211k/13.5M [00:00<?, ?B/s]
#
#
#
#
#   ...nvadersNoFrameskip-v4.zip:   2% 426k/27.2M [00:00<?, ?B/s]
#
#
#
#
#
#   ...v4/train_eval_metrics.zip:   2% 590/37.7k [00:00<?, ?B/s]
#
#   ...-v4/pytorch_variables.pth: 100% 1.26k/1.26k [00:00<?, ?B/s]
#
#
#   ...p-v4/policy.optimizer.pth:   2% 211k/13.5M [00:00<?, ?B/s]
#
#
#
#   ...NoFrameskip-v4/policy.pth:   2% 211k/13.5M [00:00<?, ?B/s]
#
#
#
#
#   ...nvadersNoFrameskip-v4.zip:   2% 426k/27.2M [00:00<?, ?B/s]
#
#
#
#
#
#   ...v4/train_eval_metrics.zip:   2% 590/37.7k [00:00<?, ?B/s]
#
#   ...-v4/pytorch_variables.pth: 100% 1.26k/1.26k [00:01<?, ?B/s]
#
#
#   ...p-v4/policy.optimizer.pth:   3% 423k/13.5M [00:00<00:37, 353kB/s]
#
#
#
#   ...NoFrameskip-v4/policy.pth:   3% 423k/13.5M [00:00<00:37, 352kB/s]
#
#
#
#
#   ...nvadersNoFrameskip-v4.zip:   3% 852k/27.2M [00:00<00:37, 710kB/s]
#
#
#
#
#
# Processing Files (1 / 5)      :   3% 1.70M/54.3M [00:02<00:55, 953kB/s,  850kB/s  ]
# New Data Upload               :   3% 1.65M/52.8M [00:02<01:02, 813kB/s,  826kB/s  ]
#
#   ...-v4/pytorch_variables.pth: 100% 1.26k/1.26k [00:01<?, ?B/s]
#
#
#   ...p-v4/policy.optimizer.pth:   5% 634k/13.5M [00:00<00:24, 529kB/s]
#
#
#
#   ...NoFrameskip-v4/policy.pth:   5% 634k/13.5M [00:00<00:24, 529kB/s]
#
#
#
#
#   ...nvadersNoFrameskip-v4.zip:   5% 1.28M/27.2M [00:00<00:24, 1.07MB/s]
#
#
#
#
#
# Processing Files (1 / 5)      :   5% 2.55M/54.3M [00:02<00:35, 1.48MB/s, 1.16MB/s  ]
# New Data Upload               :   5% 2.48M/52.8M [00:02<00:39, 1.28MB/s, 1.13MB/s  ]
#
#   ...-v4/pytorch_variables.pth: 100% 1.26k/1.26k [00:01<?, ?B/s]
#
#
#   ...p-v4/policy.optimizer.pth:  13% 1.69M/13.5M [00:00<00:07, 1.48MB/s]
#
#
#
#   ...NoFrameskip-v4/policy.pth:  13% 1.69M/13.5M [00:00<00:07, 1.48MB/s]
#
#
#
#
#   ...nvadersNoFrameskip-v4.zip:  13% 3.41M/27.2M [00:00<00:07, 2.98MB/s]
#
#
#
#
#
# Processing Files (1 / 5)      :  13% 6.79M/54.3M [00:02<00:09, 5.13MB/s, 2.83MB/s  ]
# New Data Upload               :  13% 6.61M/52.8M [00:02<00:10, 4.55MB/s, 2.76MB/s  ]
#
#   ...-v4/pytorch_variables.pth: 100% 1.26k/1.26k [00:01<?, ?B/s]
#
#
#   ...p-v4/policy.optimizer.pth:  13% 1.69M/13.5M [00:01<00:09, 1.23MB/s]
#
#
#
#   ...NoFrameskip-v4/policy.pth:  13% 1.69M/13.5M [00:01<00:09, 1.23MB/s]
#
#
#
#
#   ...nvadersNoFrameskip-v4.zip:  13% 3.41M/27.2M [00:01<00:09, 2.49MB/s]
#
#
#
#
#
#   ...v4/train_eval_metrics.zip:  13% 4.72k/37.7k [00:01<00:09, 3.44kB/s]
#
#   ...-v4/pytorch_variables.pth: 100% 1.26k/1.26k [00:01<?, ?B/s]
#
#
#   ...p-v4/policy.optimizer.pth:  17% 2.32M/13.5M [00:01<00:07, 1.51MB/s]
#
#
#
#   ...NoFrameskip-v4/policy.pth:  17% 2.32M/13.5M [00:01<00:07, 1.51MB/s]
#
#
#
#
#   ...nvadersNoFrameskip-v4.zip:  17% 4.69M/27.2M [00:01<00:07, 3.04MB/s]
#
#
#
#
#
# Processing Files (1 / 5)      :  17% 9.34M/54.3M [00:03<00:08, 5.55MB/s, 3.34MB/s  ]
# New Data Upload               :  17% 9.09M/52.8M [00:03<00:08, 5.08MB/s, 3.25MB/s  ]
#
#   ...-v4/pytorch_variables.pth: 100% 1.26k/1.26k [00:02<?, ?B/s]
#
#
#   ...p-v4/policy.optimizer.pth:  27% 3.59M/13.5M [00:01<00:04, 2.11MB/s]
#
#
#
#   ...NoFrameskip-v4/policy.pth:  27% 3.59M/13.5M [00:01<00:04, 2.11MB/s]
#
#
#
#
#   ...nvadersNoFrameskip-v4.zip:  27% 7.24M/27.2M [00:01<00:04, 4.26MB/s]
#
#
#
#
#
# Processing Files (1 / 5)      :  27% 14.4M/54.3M [00:03<00:04, 9.50MB/s, 4.81MB/s  ]
# New Data Upload               :  27% 14.0M/52.8M [00:03<00:04, 8.80MB/s, 4.68MB/s  ]
#
#   ...-v4/pytorch_variables.pth: 100% 1.26k/1.26k [00:02<?, ?B/s]
#
#
#   ...p-v4/policy.optimizer.pth:  36% 4.86M/13.5M [00:01<00:03, 2.58MB/s]
#
#
#
#   ...NoFrameskip-v4/policy.pth:  36% 4.86M/13.5M [00:01<00:03, 2.58MB/s]
#
#
#
#
#   ...nvadersNoFrameskip-v4.zip:  36% 9.80M/27.2M [00:01<00:03, 5.21MB/s]
#
#
#
#
#
# Processing Files (1 / 5)      :  36% 19.5M/54.3M [00:03<00:02, 13.0MB/s, 6.10MB/s  ]
# New Data Upload               :  36% 19.0M/52.8M [00:03<00:02, 12.2MB/s, 5.94MB/s  ]
#
#   ...-v4/pytorch_variables.pth: 100% 1.26k/1.26k [00:02<?, ?B/s]
#
#
#   ...p-v4/policy.optimizer.pth:  45% 6.13M/13.5M [00:02<00:02, 2.96MB/s]
#
#
#
#   ...NoFrameskip-v4/policy.pth:  45% 6.13M/13.5M [00:02<00:02, 2.96MB/s]
#
#
#
#
#   ...nvadersNoFrameskip-v4.zip:  45% 12.4M/27.2M [00:02<00:02, 5.96MB/s]
#
#
#
#
#
# Processing Files (1 / 5)      :  45% 24.6M/54.3M [00:03<00:01, 16.0MB/s, 7.24MB/s  ]
# New Data Upload               :  45% 24.0M/52.8M [00:03<00:01, 15.1MB/s, 7.05MB/s  ]
#
#   ...-v4/pytorch_variables.pth: 100% 1.26k/1.26k [00:02<?, ?B/s]
#
#
#   ...p-v4/policy.optimizer.pth:  45% 6.13M/13.5M [00:02<00:02, 2.69MB/s]
#
#
#
#   ...NoFrameskip-v4/policy.pth:  45% 6.13M/13.5M [00:02<00:02, 2.69MB/s]
#
#
#
#
#   ...nvadersNoFrameskip-v4.zip:  45% 12.4M/27.2M [00:02<00:02, 5.42MB/s]
#
#
#
#
#
#   ...v4/train_eval_metrics.zip:  45% 17.1k/37.7k [00:02<00:02, 7.51kB/s]
#
#   ...-v4/pytorch_variables.pth: 100% 1.26k/1.26k [00:02<?, ?B/s]
#
#
#   ...p-v4/policy.optimizer.pth:  56% 7.61M/13.5M [00:02<00:01, 3.08MB/s]
#
#
#
#   ...NoFrameskip-v4/policy.pth:  56% 7.61M/13.5M [00:02<00:01, 3.08MB/s]
#
#
#
#
#   ...nvadersNoFrameskip-v4.zip:  56% 15.3M/27.2M [00:02<00:01, 6.21MB/s]
#
#
#
#
#
# Processing Files (1 / 5)      :  56% 30.6M/54.3M [00:04<00:01, 15.5MB/s, 8.05MB/s  ]
# New Data Upload               :  56% 29.7M/52.8M [00:04<00:01, 14.9MB/s, 7.83MB/s  ]
#
#   ...-v4/pytorch_variables.pth: 100% 1.26k/1.26k [00:03<?, ?B/s]
#
#
#   ...p-v4/policy.optimizer.pth:  66% 8.88M/13.5M [00:02<00:01, 3.33MB/s]
#
#
#
#   ...NoFrameskip-v4/policy.pth:  66% 8.88M/13.5M [00:02<00:01, 3.33MB/s]
#
#
#
#
#   ...nvadersNoFrameskip-v4.zip:  66% 17.9M/27.2M [00:02<00:01, 6.72MB/s]
#
#
#
#
#
# Processing Files (1 / 5)      :  66% 35.7M/54.3M [00:04<00:01, 17.8MB/s, 8.92MB/s  ]
# New Data Upload               :  66% 34.7M/52.8M [00:04<00:01, 17.1MB/s, 8.68MB/s  ]
#
#   ...-v4/pytorch_variables.pth: 100% 1.26k/1.26k [00:03<?, ?B/s]
#
#
#   ...p-v4/policy.optimizer.pth:  75% 10.1M/13.5M [00:02<00:00, 3.55MB/s]
#
#
#
#   ...NoFrameskip-v4/policy.pth:  75% 10.1M/13.5M [00:02<00:00, 3.55MB/s]
#
#
#
#
#   ...nvadersNoFrameskip-v4.zip:  75% 20.4M/27.2M [00:02<00:00, 7.15MB/s]
#
#
#
#
#
# Processing Files (1 / 5)      :  75% 40.8M/54.3M [00:04<00:00, 19.7MB/s, 9.71MB/s  ]
# New Data Upload               :  75% 39.7M/52.8M [00:04<00:00, 18.9MB/s, 9.44MB/s  ]
#
#   ...-v4/pytorch_variables.pth: 100% 1.26k/1.26k [00:03<?, ?B/s]
#
#
#   ...p-v4/policy.optimizer.pth:  84% 11.4M/13.5M [00:02<00:00, 3.73MB/s]
#
#
#
#   ...NoFrameskip-v4/policy.pth:  84% 11.4M/13.5M [00:02<00:00, 3.73MB/s]
#
#
#
#
#   ...nvadersNoFrameskip-v4.zip:  84% 23.0M/27.2M [00:02<00:00, 7.53MB/s]
#
#
#
#
#
# Processing Files (1 / 5)      :  84% 45.9M/54.3M [00:04<00:00, 21.1MB/s, 10.4MB/s  ]
# New Data Upload               :  84% 44.6M/52.8M [00:04<00:00, 20.4MB/s, 10.1MB/s  ]
#
#   ...-v4/pytorch_variables.pth: 100% 1.26k/1.26k [00:03<?, ?B/s]
#
#
#   ...p-v4/policy.optimizer.pth:  94% 12.7M/13.5M [00:03<00:00, 3.90MB/s]
#
#
#
#   ...NoFrameskip-v4/policy.pth:  94% 12.7M/13.5M [00:03<00:00, 3.90MB/s]
#
#
#
#
#   ...nvadersNoFrameskip-v4.zip:  94% 25.6M/27.2M [00:03<00:00, 7.85MB/s]
#
#
#
#
#
# Processing Files (1 / 5)      :  94% 51.0M/54.3M [00:04<00:00, 22.3MB/s, 11.1MB/s  ]
# New Data Upload               :  94% 49.6M/52.8M [00:04<00:00, 21.6MB/s, 10.8MB/s  ]
#
#   ...-v4/pytorch_variables.pth: 100% 1.26k/1.26k [00:03<?, ?B/s]
#
#
#   ...p-v4/policy.optimizer.pth:  99% 13.3M/13.5M [00:03<00:00, 3.85MB/s]
#
#
#
#   ...NoFrameskip-v4/policy.pth:  99% 13.3M/13.5M [00:03<00:00, 3.85MB/s]
#
#
#
#
#   ...nvadersNoFrameskip-v4.zip:  99% 26.8M/27.2M [00:03<00:00, 7.77MB/s]
#
#
#
#
#
# Processing Files (1 / 5)      :  99% 53.5M/54.3M [00:05<00:00, 19.7MB/s, 11.1MB/s  ]
# New Data Upload               :  99% 52.1M/52.8M [00:05<00:00, 19.0MB/s, 10.8MB/s  ]
#
#   ...-v4/pytorch_variables.pth: 100% 1.26k/1.26k [00:04<?, ?B/s]
#
#
#   ...p-v4/policy.optimizer.pth:  99% 13.3M/13.5M [00:03<00:00, 3.64MB/s]
#
#
#
#   ...NoFrameskip-v4/policy.pth:  99% 13.3M/13.5M [00:03<00:00, 3.64MB/s]
#
#
#
#
#   ...nvadersNoFrameskip-v4.zip:  99% 26.8M/27.2M [00:03<00:00, 7.34MB/s]
#
#
#
#
#
#   ...v4/train_eval_metrics.zip:  99% 37.2k/37.7k [00:03<00:00, 10.2kB/s]
#
#   ...-v4/pytorch_variables.pth: 100% 1.26k/1.26k [00:04<?, ?B/s]
#
#
#   ...p-v4/policy.optimizer.pth:  99% 13.3M/13.5M [00:03<00:00, 3.45MB/s]
#
#
#
#   ...NoFrameskip-v4/policy.pth:  99% 13.3M/13.5M [00:03<00:00, 3.45MB/s]
#
#
#
#
#   ...nvadersNoFrameskip-v4.zip:  99% 26.8M/27.2M [00:03<00:00, 6.95MB/s]
#
#
#
#
#
#   ...v4/train_eval_metrics.zip:  99% 37.2k/37.7k [00:03<00:00, 9.63kB/s]
#
#   ...-v4/pytorch_variables.pth: 100% 1.26k/1.26k [00:04<?, ?B/s]
#
#
#   ...p-v4/policy.optimizer.pth:  99% 13.3M/13.5M [00:03<00:00, 3.28MB/s]
#
#
#
#   ...NoFrameskip-v4/policy.pth:  99% 13.3M/13.5M [00:03<00:00, 3.28MB/s]
#
#
#
#
#   ...nvadersNoFrameskip-v4.zip:  99% 26.8M/27.2M [00:03<00:00, 6.60MB/s]
#
#
#
#
#
#   ...v4/train_eval_metrics.zip:  99% 37.2k/37.7k [00:03<00:00, 9.15kB/s]
#
#   ...-v4/pytorch_variables.pth: 100% 1.26k/1.26k [00:04<?, ?B/s]
#
#
#   ...p-v4/policy.optimizer.pth: 100% 13.5M/13.5M [00:04<00:00, 3.17MB/s]
#
#
#
#   ...NoFrameskip-v4/policy.pth: 100% 13.5M/13.5M [00:04<00:00, 3.17MB/s]
#
#
#
#
#   ...nvadersNoFrameskip-v4.zip: 100% 27.2M/27.2M [00:04<00:00, 6.38MB/s]
#
#
#
#
#
# Processing Files (5 / 5)      : 100% 54.3M/54.3M [00:05<00:00, 8.19MB/s, 9.69MB/s  ]
# New Data Upload               : 100% 52.8M/52.8M [00:05<00:00, 7.96MB/s, 9.43MB/s  ]
#
#   ...-v4/pytorch_variables.pth: 100% 1.26k/1.26k [00:04<?, ?B/s]
#
#
#   ...p-v4/policy.optimizer.pth: 100% 13.5M/13.5M [00:04<00:00, 3.02MB/s]
#
#
#
#   ...NoFrameskip-v4/policy.pth: 100% 13.5M/13.5M [00:04<00:00, 3.02MB/s]
#
#
#
#
#   ...nvadersNoFrameskip-v4.zip: 100% 27.2M/27.2M [00:04<00:00, 6.09MB/s]
#
#
#
#
#
#   ...v4/train_eval_metrics.zip: 100% 37.7k/37.7k [00:04<00:00, 8.44kB/s]
#
#   ...-v4/pytorch_variables.pth: 100% 1.26k/1.26k [00:05<?, ?B/s]
#
#
#   ...p-v4/policy.optimizer.pth: 100% 13.5M/13.5M [00:04<00:00, 2.99MB/s]
#
#
#
#   ...NoFrameskip-v4/policy.pth: 100% 13.5M/13.5M [00:04<00:00, 2.99MB/s]
#
#
#
#
#   ...nvadersNoFrameskip-v4.zip: 100% 27.2M/27.2M [00:04<00:00, 6.03MB/s]
#
#
#
#
#
#   ...v4/train_eval_metrics.zip: 100% 37.7k/37.7k [00:04<00:00, 8.36kB/s]
#
#   ...-v4/pytorch_variables.pth: 100% 1.26k/1.26k [00:05<?, ?B/s]
#
#
#   ...p-v4/policy.optimizer.pth: 100% 13.5M/13.5M [00:04<00:00, 2.89MB/s]
#
#
#
#   ...NoFrameskip-v4/policy.pth: 100% 13.5M/13.5M [00:04<00:00, 2.89MB/s]
#
#
#
#
#   ...nvadersNoFrameskip-v4.zip: 100% 27.2M/27.2M [00:04<00:00, 5.83MB/s]
#
#
#
#
#
# Processing Files (5 / 5)      : 100% 54.3M/54.3M [00:06<00:00, 8.74MB/s, 9.05MB/s  ]
# New Data Upload               : 100% 52.8M/52.8M [00:06<00:00, 8.50MB/s, 8.80MB/s  ]
#   ...-v4/pytorch_variables.pth: 100% 1.26k/1.26k [00:05<?, ?B/s]
#   ...p-v4/policy.optimizer.pth: 100% 13.5M/13.5M [00:04<00:00, 2.89MB/s]
#   ...NoFrameskip-v4/policy.pth: 100% 13.5M/13.5M [00:04<00:00, 2.89MB/s]
#   ...nvadersNoFrameskip-v4.zip: 100% 27.2M/27.2M [00:04<00:00, 5.82MB/s]
#   ...v4/train_eval_metrics.zip: 100% 37.7k/37.7k [00:04<00:00, 8.07kB/s]
# ℹ Your model is pushed to the hub. You can view your model here:
# https://huggingface.co/KraTUZen/dqn-SpaceInvadersNoFrameskip-v4

# %% [markdown]
# Congrats 🥳 you've just trained and uploaded your first Deep Q-Learning agent using RL-Baselines-3 Zoo. The script above should have displayed a link to a model repository such as https://huggingface.co/KraTUZenn/dqn-SpaceInvadersNoFrameskip-v4. When you go to this link, you can:
#
# - See a **video preview of your agent** at the right.
# - Click "Files and versions" to see all the files in the repository.
# - Click "Use in stable-baselines3" to get a code snippet that shows how to load the model.
# - A model card (`README.md` file) which gives a description of the model and the hyperparameters you used.
#
# Under the hood, the Hub uses git-based repositories (don't worry if you don't know what git is), which means you can update the model with new versions as you experiment and improve your agent.
#
# **Compare the results of your agents with your classmates** using the [leaderboard](https://huggingface.co/spaces/huggingface-projects/Deep-Reinforcement-Learning-Leaderboard) 🏆

# %% [markdown]
# ## Load a powerful trained model 🔥
# - The Stable-Baselines3 team uploaded **more than 150 trained Deep Reinforcement Learning agents on the Hub**.
#
# You can find them here: 👉 https://huggingface.co/sb3
#
# Some examples:
# - Asteroids: https://huggingface.co/sb3/dqn-AsteroidsNoFrameskip-v4
# - Beam Rider: https://huggingface.co/sb3/dqn-BeamRiderNoFrameskip-v4
# - Breakout: https://huggingface.co/sb3/dqn-BreakoutNoFrameskip-v4
# - Road Runner: https://huggingface.co/sb3/dqn-RoadRunnerNoFrameskip-v4
#
# Let's load an agent playing Beam Rider: https://huggingface.co/sb3/dqn-BeamRiderNoFrameskip-v4

# %%
# %%html
# <video controls autoplay><source src="https://huggingface.co/sb3/dqn-BeamRiderNoFrameskip-v4/resolve/main/replay.mp4" type="video/mp4"></video>
# Out:
# <video controls autoplay><source src="https://huggingface.co/sb3/dqn-BeamRiderNoFrameskip-v4/resolve/main/replay.mp4" type="video/mp4"></video>

# %% [markdown]
# 1. We download the model using `rl_zoo3.load_from_hub`, and place it in a new folder that we can call `rl_trained`

# %%
# Download model and save it into the logs/ folder
# !python -m rl_zoo3.load_from_hub --algo dqn --env BeamRiderNoFrameskip-v4 -orga sb3 -f rl_trained/
# Out:
# 2026-03-05 08:50:17.179829: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1772700617.200418   22145 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1772700617.207314   22145 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1772700617.224809   22145 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1772700617.224832   22145 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1772700617.224836   22145 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1772700617.224840   22145 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-03-05 08:50:17.229512: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.
# Downloading from https://huggingface.co/sb3/dqn-BeamRiderNoFrameskip-v4
# No normalization file
# Saving to rl_trained/dqn/BeamRiderNoFrameskip-v4_2

# %% [markdown]
# 2. Let's evaluate if for 5000 timesteps

# %%
# !python -m rl_zoo3.enjoy --algo dqn --env BeamRiderNoFrameskip-v4 -n 5000  -f rl_trained/ --no-render
# Out:
# 2026-03-05 08:50:29.353542: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1772700629.374627   22206 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1772700629.381449   22206 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1772700629.398655   22206 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1772700629.398680   22206 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1772700629.398684   22206 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1772700629.398687   22206 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-03-05 08:50:29.403071: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.
# Loading latest experiment, id=2
# Loading rl_trained/dqn/BeamRiderNoFrameskip-v4_2/BeamRiderNoFrameskip-v4.zip
# A.L.E: Arcade Learning Environment (version 0.11.2+ecc1138)
# [Powered by Stella]
# Stacking 4 frames
# /usr/local/lib/python3.12/dist-packages/stable_baselines3/common/save_util.py:167: UserWarning: Could not deserialize object exploration_schedule. Consider using `custom_objects` argument to replace this object.
# Exception: code expected at least 16 arguments, got 15
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/stable_baselines3/common/vec_env/patch_gym.py:95: UserWarning: You loaded a model that was trained using OpenAI Gym. We strongly recommend transitioning to Gymnasium by saving that model again.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/stable_baselines3/common/base_class.py:773: UserWarning: You are probably loading a DQN model saved with SB3 < 2.4.0, we truncated the optimizer state so you can save the model again to avoid issues in the future (see https://github.com/DLR-RM/stable-baselines3/pull/1963 for more info). Original error: loaded state dict contains a parameter group that doesn't match the size of optimizer's group
# Note: the model should still work fine, this only a warning.
#   warnings.warn(
# Atari Episode Score: 3028.00
# Atari Episode Length 14816

# %%
# Zip the entire content folder
# !zip -r unit3.zip /content

# Download the zip file
from google.colab import files
files.download("unit3.zip")
# Out:
#   adding: content/ (stored 0%)
#   adding: content/.config/ (stored 0%)
#   adding: content/.config/configurations/ (stored 0%)
#   adding: content/.config/configurations/config_default (deflated 15%)
#   adding: content/.config/.last_opt_in_prompt.yaml (stored 0%)
#   adding: content/.config/.last_update_check.json (deflated 25%)
#   adding: content/.config/gce (stored 0%)
#   adding: content/.config/.last_survey_prompt.yaml (stored 0%)
#   adding: content/.config/hidden_gcloud_config_universe_descriptor_data_cache_configs.db (deflated 97%)
#   adding: content/.config/config_sentinel (stored 0%)
#   adding: content/.config/default_configs.db (deflated 98%)
#   adding: content/.config/logs/ (stored 0%)
#   adding: content/.config/logs/2026.02.06/ (stored 0%)
#   adding: content/.config/logs/2026.02.06/14.31.35.535753.log (deflated 58%)
#   adding: content/.config/logs/2026.02.06/14.31.44.938153.log (deflated 57%)
#   adding: content/.config/logs/2026.02.06/14.31.19.332851.log (deflated 58%)
#   adding: content/.config/logs/2026.02.06/14.31.45.734270.log (deflated 56%)
#   adding: content/.config/logs/2026.02.06/14.30.32.592228.log (deflated 92%)
#   adding: content/.config/logs/2026.02.06/14.31.28.771044.log (deflated 86%)
#   adding: content/.config/active_config (stored 0%)
#   adding: content/rl_trained/ (stored 0%)
#   adding: content/rl_trained/dqn/ (stored 0%)
#   adding: content/rl_trained/dqn/BeamRiderNoFrameskip-v4_1/ (stored 0%)
#   adding: content/rl_trained/dqn/BeamRiderNoFrameskip-v4_1/0.monitor.csv (deflated 56%)
#   adding: content/rl_trained/dqn/BeamRiderNoFrameskip-v4_1/BeamRiderNoFrameskip-v4/ (stored 0%)
#   adding: content/rl_trained/dqn/BeamRiderNoFrameskip-v4_1/BeamRiderNoFrameskip-v4/env_kwargs.yml (stored 0%)
#   adding: content/rl_trained/dqn/BeamRiderNoFrameskip-v4_1/BeamRiderNoFrameskip-v4/args.yml (deflated 57%)
#   adding: content/rl_trained/dqn/BeamRiderNoFrameskip-v4_1/BeamRiderNoFrameskip-v4/config.yml (deflated 51%)
#   adding: content/rl_trained/dqn/BeamRiderNoFrameskip-v4_1/evaluations.npz (deflated 72%)
#   adding: content/rl_trained/dqn/BeamRiderNoFrameskip-v4_1/BeamRiderNoFrameskip-v4.zip (stored 0%)
#   adding: content/rl_trained/dqn/BeamRiderNoFrameskip-v4_2/ (stored 0%)
#   adding: content/rl_trained/dqn/BeamRiderNoFrameskip-v4_2/0.monitor.csv (deflated 56%)
#   adding: content/rl_trained/dqn/BeamRiderNoFrameskip-v4_2/BeamRiderNoFrameskip-v4/ (stored 0%)
#   adding: content/rl_trained/dqn/BeamRiderNoFrameskip-v4_2/BeamRiderNoFrameskip-v4/env_kwargs.yml (stored 0%)
#   adding: content/rl_trained/dqn/BeamRiderNoFrameskip-v4_2/BeamRiderNoFrameskip-v4/args.yml (deflated 57%)
#   adding: content/rl_trained/dqn/BeamRiderNoFrameskip-v4_2/BeamRiderNoFrameskip-v4/config.yml (deflated 51%)
#   adding: content/rl_trained/dqn/BeamRiderNoFrameskip-v4_2/evaluations.npz (deflated 72%)
#   adding: content/rl_trained/dqn/BeamRiderNoFrameskip-v4_2/BeamRiderNoFrameskip-v4.zip (stored 0%)
#   adding: content/hub/ (stored 0%)
#   adding: content/hub/dqn-SpaceInvadersNoFrameskip-v4/ (stored 0%)
#   adding: content/hub/dqn-SpaceInvadersNoFrameskip-v4/dqn-SpaceInvadersNoFrameskip-v4.zip (stored 0%)
#   adding: content/hub/dqn-SpaceInvadersNoFrameskip-v4/env_kwargs.yml (stored 0%)
#   adding: content/hub/dqn-SpaceInvadersNoFrameskip-v4/.cache/ (stored 0%)
#   adding: content/hub/dqn-SpaceInvadersNoFrameskip-v4/.cache/huggingface/ (stored 0%)
#   adding: content/hub/dqn-SpaceInvadersNoFrameskip-v4/.cache/huggingface/download/ (stored 0%)
#   adding: content/hub/dqn-SpaceInvadersNoFrameskip-v4/.cache/huggingface/download/.gitattributes.metadata (deflated 25%)
#   adding: content/hub/dqn-SpaceInvadersNoFrameskip-v4/.cache/huggingface/.gitignore (stored 0%)
#   adding: content/hub/dqn-SpaceInvadersNoFrameskip-v4/args.yml (deflated 62%)
#   adding: content/hub/dqn-SpaceInvadersNoFrameskip-v4/dqn-SpaceInvadersNoFrameskip-v4/ (stored 0%)
#   adding: content/hub/dqn-SpaceInvadersNoFrameskip-v4/dqn-SpaceInvadersNoFrameskip-v4/system_info.txt (deflated 20%)
#   adding: content/hub/dqn-SpaceInvadersNoFrameskip-v4/dqn-SpaceInvadersNoFrameskip-v4/policy.optimizer.pth (deflated 68%)
#   adding: content/hub/dqn-SpaceInvadersNoFrameskip-v4/dqn-SpaceInvadersNoFrameskip-v4/_stable_baselines3_version (stored 0%)
#   adding: content/hub/dqn-SpaceInvadersNoFrameskip-v4/dqn-SpaceInvadersNoFrameskip-v4/pytorch_variables.pth (deflated 68%)
#   adding: content/hub/dqn-SpaceInvadersNoFrameskip-v4/dqn-SpaceInvadersNoFrameskip-v4/data (deflated 96%)
#   adding: content/hub/dqn-SpaceInvadersNoFrameskip-v4/dqn-SpaceInvadersNoFrameskip-v4/policy.pth (deflated 7%)
#   adding: content/hub/dqn-SpaceInvadersNoFrameskip-v4/.gitattributes (deflated 87%)
#   adding: content/hub/dqn-SpaceInvadersNoFrameskip-v4/train_eval_metrics.zip (stored 0%)
#   adding: content/hub/dqn-SpaceInvadersNoFrameskip-v4/README.md (deflated 64%)
#   adding: content/hub/dqn-SpaceInvadersNoFrameskip-v4/results.json (deflated 20%)
#   adding: content/hub/dqn-SpaceInvadersNoFrameskip-v4/config.yml (deflated 51%)
#   adding: content/dqn.yaml (deflated 40%)
#   adding: content/logs/ (stored 0%)
#   adding: content/logs/dqn/ (stored 0%)
#   adding: content/logs/dqn/SpaceInvadersNoFrameskip-v4_1/ (stored 0%)
#   adding: content/logs/dqn/SpaceInvadersNoFrameskip-v4_1/SpaceInvadersNoFrameskip-v4.zip (stored 0%)
#   adding: content/logs/dqn/SpaceInvadersNoFrameskip-v4_1/0.monitor.csv (deflated 56%)
#   adding: content/logs/dqn/SpaceInvadersNoFrameskip-v4_1/SpaceInvadersNoFrameskip-v4/ (stored 0%)
#   adding: content/logs/dqn/SpaceInvadersNoFrameskip-v4_1/SpaceInvadersNoFrameskip-v4/args.yml (deflated 62%)
#   adding: content/logs/dqn/SpaceInvadersNoFrameskip-v4_1/SpaceInvadersNoFrameskip-v4/command.txt (deflated 4%)
#   adding: content/logs/dqn/SpaceInvadersNoFrameskip-v4_1/SpaceInvadersNoFrameskip-v4/config.yml (deflated 51%)
#   adding: content/logs/dqn/SpaceInvadersNoFrameskip-v4_1/best_model.zip (stored 0%)
#   adding: content/logs/dqn/SpaceInvadersNoFrameskip-v4_1/evaluations.npz (deflated 68%)
#   adding: content/.ipynb_checkpoints/ (stored 0%)
#   adding: content/sample_data/ (stored 0%)
#   adding: content/sample_data/anscombe.json (deflated 83%)
#   adding: content/sample_data/README.md (deflated 39%)
#   adding: content/sample_data/mnist_test.csv (deflated 88%)
#   adding: content/sample_data/california_housing_train.csv (deflated 79%)
#   adding: content/sample_data/mnist_train_small.csv (deflated 88%)
#   adding: content/sample_data/california_housing_test.csv (deflated 76%)

# %% [markdown]
# Why not trying to train your own **Deep Q-Learning Agent playing BeamRiderNoFrameskip-v4? 🏆.**
#
# If you want to try, check https://huggingface.co/sb3/dqn-BeamRiderNoFrameskip-v4#hyperparameters **in the model card, you have the hyperparameters of the trained agent.**

# %% [markdown]
# But finding hyperparameters can be a daunting task. Fortunately, we'll see in the next Unit, how we can **use Optuna for optimizing the Hyperparameters 🔥.**

# %% [markdown]
# ## Some additional challenges 🏆
# The best way to learn **is to try things by your own**!
#
# In the [Leaderboard](https://huggingface.co/spaces/huggingface-projects/Deep-Reinforcement-Learning-Leaderboard) you will find your agents. Can you get to the top?
#
# Here's a list of environments you can try to train your agent with:
# - BeamRiderNoFrameskip-v4
# - BreakoutNoFrameskip-v4
# - EnduroNoFrameskip-v4
# - PongNoFrameskip-v4
#
# Also, **if you want to learn to implement Deep Q-Learning by yourself**, you definitely should look at CleanRL implementation: https://github.com/vwxyzjn/cleanrl/blob/master/cleanrl/dqn_atari.py
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/unit4/atari-envs.gif" alt="Environments"/>

# %% [markdown]
# ________________________________________________________________________
# Congrats on finishing this chapter!
#
# If you’re still feel confused with all these elements...it's totally normal! **This was the same for me and for all people who studied RL.**
#
# Take time to really **grasp the material before continuing and try the additional challenges**. It’s important to master these elements and having a solid foundations.
#
# In the next unit, **we’re going to learn about [Optuna](https://optuna.org/)**. One of the most critical task in Deep Reinforcement Learning is to find a good set of training hyperparameters. And Optuna is a library that helps you to automate the search.

# %% [markdown]
# ### This is a course built with you 👷🏿‍♀️
#
# Finally, we want to improve and update the course iteratively with your feedback. If you have some, please fill this form 👉 https://forms.gle/3HgA7bEHwAmmLfwh9
#
# We're constantly trying to improve our tutorials, so **if you find some issues in this notebook**, please [open an issue on the Github Repo](https://github.com/huggingface/deep-rl-class/issues).

# %% [markdown]
# See you on Bonus unit 2! 🔥

# %% [markdown]
# ### Keep Learning, Stay Awesome 🤗
